# %%
#geeksforgeeks

#unlike linear data structures, trees have many ways to traverse them

#      1
#     / \
#    2   3
#   / \
#  4   5

#depth first traversals:
#INORDER (left, root, right): 42513
#PREORDER (root, left, right): 12453
#POSTORDER (left, right, root): 45231

#breadth first or level order traversal: 12345

# %%
#Algorithm Inorder
#1. Traverse the left subtree, call Inorder(in left)
#2. Visit the root
#3. Traverse the right subtree, call Inorder(in right)
#used for non-decreasing order

#Algorithm Preorder
#1. Vist the root
#2. Traverse the left, call Preorder(in left)
#3. Traverse the right, call Preorder(in right)
#used to copy the tree

#Algorithm  Postorder
#1. Traverse the left subtree, call Postorder(in left)
#2. Traverse the right subtree, call Postorder(in right)
#3. Visit the root
#used to delete the tree

# %%
class TreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None
        
        
def printInorder(root):
    
    if root:
        
        #first recur on left child
        printInorder(root.left)
        
        #then print the root
        print(root.data)
        
        #now the r child
        printInorder(root.right)
        
        
def printPostorder(root):
    
    if root:
        
        printPostorder(root.left)
        
        printPostorder(root.right)
        
        print(root.data)
        
        
def printPreorder(root):
    
    if root:
        
        print(root.data)
        
        printPreorder(root.left)
        
        printPreorder(root.right)
        
        
root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)

print("Preorder is:")
printPreorder(root)

print("\nInorder is:")
printInorder(root)

print("\nPostorder is:")
printPostorder(root)
# Out:
# Preorder is:
# 1
# 2
# 4
# 5
# 3
#
# Inorder is:
# 4
# 2
# 5
# 1
# 3
#
# Postorder is:
# 4
# 5
# 2
# 3
# 1

# %%
#askpython.com

#Inorder Traversal - INCREASING ORDER
#left->root->right

#Algorithm inorder:
#Input: reference to the root node
#Output: prints all the nodes of the tree
#Start.
#1. If root is empty, return
#2. Traverse left subtree of the root. // inorder(root.leftChild)
#3. Traverse the root node. // print val at the node
#4. Traverse the right subtree of the root. // inorder(root.rightChild)
#End

# %%
#Implementation                 MY CODE
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None
        
def inorder(root):
    
    if root is not None:
        
        inorder(root.left)
        
        print(root.val)
        
        inorder(root.right)
        
    else:
        return root
    
root = TreeNode(15)
root.left = TreeNode(10)
root.right = TreeNode(25)
root.left.left = TreeNode(6)
root.left.right = TreeNode(14)
root.right.left = TreeNode(20)
root.right.right = TreeNode(60)

inorder(root)
# Out:
# 6
# 10
# 14
# 15
# 20
# 25
# 60

# %%
#Implementation MY CODE+THEIR SUGGESTIONS
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None
        
#firstly they wanted the fun that inserts the next nodes
def insert(root, new_val):

    
    #what if the tree is empty?
    #make it a new root
    if root is None:
        root = TreeNode(new_val)
        return root
    
    #now we know tree is not empty - insert
    #iinsert tot he left if you know the new data is less than the root
    if new_val < root.val:
        root.left = insert(root.left, new_val)
        
    #now we know its not empty and the new data is more than the root
    #insert it then to the right
    else:
        root.right = insert(root.right, new_val)
        
    return root


def inorder(root):
    
    if root == None:
        return
    
    inorder(root.left)
    print(root.val)
    inorder(root.right)
    
root = insert(None, 15)
insert(root, 10)
insert(root, 25)
insert(root, 14)
insert(root, 6)
insert(root, 20)
insert(root, 60)

inorder(root)
# Out:
# 6
# 10
# 14
# 15
# 20
# 25
# 60
